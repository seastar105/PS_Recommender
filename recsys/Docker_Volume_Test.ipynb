# %%
import os
import json
import requests
import time
import sqlclient
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-6-153eb4b9eed4> in <module>
#       3 import requests
#       4 import time
# ----> 5 import sqlclient
#
# ModuleNotFoundError: No module named 'sqlclient'

# %%
path = "solved_data/user_tags/user_01000.json"
with open(path, "r", encoding="utf-8") as f:
    user = json.load(f)
print(json.dumps(user, indent=2, ensure_ascii=False))
# Out:
# {
#   "count": 179,
#   "items": [
#     {
#       "tag": {
#         "key": "data_structures",
#         "isMeta": false,
#         "bojTagId": 175,
#         "problemCount": 1765,
#         "displayNames": [
#           {
#             "language": "en",
#             "name": "data structures",
#             "short": "ds"
#           },
#           {
#             "language": "ko",
#             "name": "자료 구조",
#             "short": "자료 구조"
#           }
#         ],
#         "aliases": [
#           {
#             "alias": "자료구조"
#           }
#         ]
#       },
#       "total": 1765,
#       "solved": 73,
#       "partial": 0,
#       "tried": 2,
#       "exp": 8189325
#     },
#     {
#       "tag": {
#         "key": "segtree",
#         "isMeta": false,
#         "bojTagId": 65,
#         "problemCount": 692,
#         "displayNames": [
#           {
#             "language": "en",
#             "name": "segment tree",
#             "short": "segtree"
#           },
# ...
